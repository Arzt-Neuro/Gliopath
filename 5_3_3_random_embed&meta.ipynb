# %%
import torch
import os
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

os.chdir('F:\\workspace\\pathology\\gigapath')

# %%
df = pd.DataFrame({
    'id': [f"sample_{i:04d}" for i in range(1, 201)],
    'slide_addr': [f"data/wsi/sample_{i:03d}.svs" for i in range(1, 201)],
    'tumour_type': np.random.choice(['glioma', 'ependymoma', 'glioblastoma', 'meningioma', 'normal'], 200),
    'duration': np.random.gamma(1.5, 24, 200).astype(int),
    'IDH1': np.random.choice([0, 1], 200),
    'TP53': np.random.choice([0, 1], 200),
    'ATRX': np.random.choice([0, 1], 200),
    'PTEN': np.random.choice([0, 1], 200),
    'EGFR': np.random.choice([0, 1], 200),
    'TERT': np.random.choice([0, 1], 200),
    'created_date': pd.date_range('2014-01-01', periods=200, freq='D'),
    'quality_score': np.random.uniform(0.5, 1.0, 200)
})

df.to_csv('data\\metadata.tbl', sep='\t', index=False)
df
# Out:
#               id               slide_addr   tumour_type  duration  IDH1  TP53  \
# 0    sample_0001  data/wsi/sample_001.svs        glioma        39     1     1
# 1    sample_0002  data/wsi/sample_002.svs        glioma        19     1     1
# 2    sample_0003  data/wsi/sample_003.svs    meningioma        47     0     0
# 3    sample_0004  data/wsi/sample_004.svs    ependymoma        34     0     1
# 4    sample_0005  data/wsi/sample_005.svs        normal        77     0     1
# ..           ...                      ...           ...       ...   ...   ...
# 195  sample_0196  data/wsi/sample_196.svs    meningioma        33     0     0
# 196  sample_0197  data/wsi/sample_197.svs    meningioma        21     1     1
# 197  sample_0198  data/wsi/sample_198.svs    ependymoma        25     0     1
# 198  sample_0199  data/wsi/sample_199.svs    meningioma        20     0     0
# 199  sample_0200  data/wsi/sample_200.svs  glioblastoma        19     1     1
#
#      ATRX  PTEN  EGFR  TERT created_date  quality_score
# 0       0     0     1     1   2014-01-01       0.661797
# 1       0     0     1     0   2014-01-02       0.911148
# 2       1     1     0     1   2014-01-03       0.506143
# 3       1     1     0     1   2014-01-04       0.913237
# 4       1     0     1     0   2014-01-05       0.629299
# ..    ...   ...   ...   ...          ...            ...
# 195     1     1     0     1   2014-07-15       0.791321
# 196     1     1     0     0   2014-07-16       0.967144
# 197     1     0     1     1   2014-07-17       0.500449
# 198     1     0     0     1   2014-07-18       0.870751
# 199     1     1     1     0   2014-07-19       0.802836
#
# [200 rows x 12 columns]

# %%
# test dataset
df_test = pd.DataFrame({
    'id': [f"sample_{i:04d}" for i in range(1001, 1051)],
    'slide_addr': [f"data/wsi/sample_{i:03d}.svs" for i in range(1001, 1051)],
    'tumour_type': np.random.choice(['glioma', 'ependymoma', 'glioblastoma', 'meningioma', 'normal'], 50),
    'duration': np.random.gamma(1.5, 24, 50).astype(int),
    'IDH1': np.random.choice([0, 1], 50),
    'TP53': np.random.choice([0, 1], 50),
    'ATRX': np.random.choice([0, 1], 50),
    'PTEN': np.random.choice([0, 1], 50),
    'EGFR': np.random.choice([0, 1], 50),
    'TERT': np.random.choice([0, 1], 50),
    'created_date': pd.date_range('2014-01-01', periods=50, freq='D'),
    'quality_score': np.random.uniform(0.5, 1.0, 50)
})

df_test.to_csv('data\\metadata_test.tbl', sep='\t', index=False)
df_test

# %% [markdown]
# ## tile embeddings

# %%
# Pattern: intercept + 256 * tile_seq
def generate_coordinate_list(x_range, y_range, TILE_SIZE=256, x_intercept=3072, y_intercept=7808):
    """
    Generate a list of starting pixel coordinates for tiles.

    Args:
        x_range: tuple (min_tiles, max_tiles) for x-axis
        y_range: tuple (min_tiles, max_tiles) for y-axis
        x_intercept: starting x coordinate
        y_intercept: starting y coordinate

    Returns:
        List of (x, y) coordinate tuples
    """
    coordinates = []

    for x_tile in range(x_range[0], x_range[1]):
        x_coord = x_intercept + TILE_SIZE * x_tile

        for y_tile in range(y_range[0], y_range[1]):
            y_coord = y_intercept + TILE_SIZE * y_tile
            coordinates.append((x_coord, y_coord))

    return coordinates

# Generate the coordinate list
# Adjust these ranges to match your slide dimensions
coordinate_list = generate_coordinate_list(
    x_range=(0, 1000),  # Adjust based on your slide width
    y_range=(0, 1000),  # Adjust based on your slide height
    x_intercept=3072,
    y_intercept=7808
)

# %%
for i in range(1,201):
    nrows = np.random.poisson(lam=275)
    ncols = 1536
    row_seq = random.sample(range(1000), nrows)

    embeds = torch.randn(nrows, ncols)
    coords = torch.tensor(np.array([coordinate_list[i] for i in row_seq]))
    sample_dict = {'tile_embeds': embeds, 'coords': coords}

    torch.save(sample_dict, 'output\\tiles\\rand_embed\\' + f'sample_{i:04d}.pt')

# %%
for i in range(1001, 1051):
    nrows = np.random.poisson(lam=275)
    ncols = 1536
    row_seq = random.sample(range(1000), nrows)

    embeds = torch.randn(nrows, ncols)
    coords = torch.tensor(np.array([coordinate_list[i] for i in row_seq]))
    sample_dict = {'tile_embeds': embeds, 'coords': coords}

    torch.save(sample_dict, 'output\\tiles\\rand_embed\\' + f'sample_{i:04d}.pt')

# %% [markdown]
# ## load & save model

# %%
os.chdir('F:\\workspace\\pathology\\gigapath\\code\\transfer')
from gliopath.models.load import giga_slide_enc
os.chdir('F:\\workspace\\pathology\\gigapath')
model = giga_slide_enc(path='model/pub/slide_encoder.pth', global_pool=True)
model.eval()
# Out:
# F:\conda\gliopath\Lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# F:\conda\gliopath\Lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# F:\workspace\pathology\gigapath
# dilated_ratio:  [1, 2, 4, 8, 16]
# segment_length:  [np.int64(1024), np.int64(5792), np.int64(32768), np.int64(185363), np.int64(1048576)]
# Number of trainable LongNet parameters:  85148160
# Global Pooling: True
#  Pretrained weights not found at local-dir:model/pub/slide_encoder.pth. Randomly initialized the model!
# Slide encoder param # 86330880

# %% [markdown]
# ## lean model

# %%
# ============================================
# STEP 1: Aggressive Pruning (Remove 70-90% of weights)
# ============================================
import torch.nn.utils.prune as prune
import torch.nn as nn

def prune_model(model, amount=0.8):  # Remove 80% of weights
    for name, module in model.named_modules():
        if isinstance(module, (nn.Linear, nn.Conv2d)):
            prune.l1_unstructured(module, name='weight', amount=amount)
            if hasattr(module, 'bias') and module.bias is not None:
                prune.l1_unstructured(module, name='bias', amount=amount)
            # Make pruning permanent
            prune.remove(module, 'weight')
            if hasattr(module, 'bias') and module.bias is not None:
                prune.remove(module, 'bias')
    return model

model = prune_model(model, amount=0.8)

# %%
# ============================================
# STEP 2: INT8 Quantization (8x memory reduction)
# ============================================
# Dynamic quantization
quantized_model = torch.quantization.quantize_dynamic(
    model,
    {nn.Linear, nn.Conv2d, nn.LSTM, nn.GRU},  # All major layer types
    dtype=torch.qint8
)

# %%
# ============================================
# STEP 3: Half Precision for remaining float layers
# ============================================
quantized_model = quantized_model.half()

# %%
import bitsandbytes as bnb

# Replace Linear layers with 4-bit versions
def replace_linear_with_4bit(model):
    for name, module in model.named_children():
        if isinstance(module, nn.Linear):
            # Replace with 4-bit quantized version
            new_module = bnb.nn.Linear4bit(
                module.in_features,
                module.out_features,
                bias=module.bias is not None
            )
            setattr(model, name, new_module)
        else:
            replace_linear_with_4bit(module)
    return model

quantized_model = replace_linear_with_4bit(quantized_model)

# %%
# ============================================
# STEP 4: Save optimized model
# ============================================
torch.save(quantized_model.state_dict(), 'model\\slide_encoder_lite.pth')

# %%
model = giga_slide_enc(path='model\\slide_encoder_lite.pth', global_pool=True)
# Out:
# F:\workspace\pathology\gigapath
# dilated_ratio:  [1, 2, 4, 8, 16]
# segment_length:  [np.int64(1024), np.int64(5792), np.int64(32768), np.int64(185363), np.int64(1048576)]
# Number of trainable LongNet parameters:  85148160
# Global Pooling: True
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model = giga_slide_enc(path='model\\slide_encoder_lite.pth', global_pool=True)
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\load.py:17, in giga_slide_enc(path, global_pool)
#      15 def giga_slide_enc(path: str='', global_pool=False):
#      16     print(os.getcwd())
# ---> 17     slide_encoder_model = longn.glio_create_model(f"local-dir:{path}", "gigapath_slide_enc12l768d", 1536, global_pool=global_pool)
#      18     print("Slide encoder param #", sum(p.numel() for p in slide_encoder_model.parameters()))
#      20     return slide_encoder_model
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:375, in glio_create_model(local_path, model_arch, in_chans, local_dir, **kwargs)
#     374 def glio_create_model(local_path: str, model_arch: str, in_chans: int, local_dir: str = os.path.join(os.path.expanduser("~"), ".cache/"), **kwargs):
# --> 375     model = timm.create_model(model_arch, pretrained=False, in_chans=in_chans, **kwargs)
#     377     if os.path.exists(local_path):
#     378         state_dict = torch.load(local_path, map_location="cpu")["model"]
#
# File F:\conda\gliopath\Lib\site-packages\timm\models\_factory.py:138, in create_model(model_name, pretrained, pretrained_cfg, pretrained_cfg_overlay, checkpoint_path, cache_dir, scriptable, exportable, no_jit, **kwargs)
#     136 create_fn = model_entrypoint(model_name)
#     137 with set_layer_config(scriptable=scriptable, exportable=exportable, no_jit=no_jit):
# --> 138     model = create_fn(
#     139         pretrained=pretrained,
#     140         pretrained_cfg=pretrained_cfg,
#     141         pretrained_cfg_overlay=pretrained_cfg_overlay,
#     142         cache_dir=cache_dir,
#     143         **kwargs,
#     144     )
#     146 if checkpoint_path:
#     147     load_checkpoint(model, checkpoint_path)
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:398, in gigapath_slide_enc12l768d(**kwargs)
#     396 @register_model
#     397 def gigapath_slide_enc12l768d(**kwargs):
# --> 398     model = LongNetViT(embed_dim=768, depth=12, mlp_ratio=4, norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     399     return model
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:265, in LongNetViT.__init__(self, in_chans, embed_dim, depth, slide_ngrids, tile_size, max_wsi_size, norm_layer, global_pool, dropout, drop_path_rate, **kwargs)
#     262 self.global_pool = global_pool
#     263 print("Global Pooling:", self.global_pool)
# --> 265 self.initialize_vit_weights()
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:270, in LongNetViT.initialize_vit_weights(self)
#     267 def initialize_vit_weights(self):
#     268     # initialization
#     269     # initialize (and freeze) pos_embed by sin-cos embedding
# --> 270     pos_embed = get_2d_sincos_pos_embed(self.pos_embed.shape[-1], self.slide_ngrids, cls_token=True)
#     271     self.pos_embed.data.copy_(torch.from_numpy(pos_embed).float().unsqueeze(0))
#     273     # initialize patch_embed like nn.Linear (instead of nn.Conv2d)
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:191, in get_2d_sincos_pos_embed(embed_dim, grid_size, cls_token)
#     188 grid = np.stack(grid, axis=0)
#     190 grid = grid.reshape([2, 1, grid_size, grid_size])
# --> 191 pos_embed = get_2d_sincos_pos_embed_from_grid(embed_dim, grid)
#     192 if cls_token:
#     193     pos_embed = np.concatenate([np.zeros([1, embed_dim]), pos_embed], axis=0)
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:173, in get_2d_sincos_pos_embed_from_grid(embed_dim, grid)
#     171 # use half of dimensions to encode grid_h
#     172 emb_h = get_1d_sincos_pos_embed_from_grid(embed_dim // 2, grid[0])  # (H*W, D/2)
# --> 173 emb_w = get_1d_sincos_pos_embed_from_grid(embed_dim // 2, grid[1])  # (H*W, D/2)
#     175 emb = np.concatenate([emb_h, emb_w], axis=1)  # (H*W, D)
#     176 return emb
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:164, in get_1d_sincos_pos_embed_from_grid(embed_dim, pos)
#     161 emb_sin = np.sin(out)  # (M, D/2)
#     162 emb_cos = np.cos(out)  # (M, D/2)
# --> 164 emb = np.concatenate([emb_sin, emb_cos], axis=1)  # (M, D)
#     165 return emb
#
# MemoryError: Unable to allocate 2.86 GiB for an array with shape (1000000, 384) and data type float64

# %%
import timm
import gliopath.models.longn
timm.list_models('*gigapath*')
# Out:
# F:\conda\gliopath\Lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# F:\conda\gliopath\Lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
timm.create_model('gigapath_slide_enc3l32d', pretrained=False, in_chans=1536, global_pool=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 timm.create_model('gigapath_slide_enc5l64d', pretrained=False, in_chans=1536, global_pool=True)
#
# File F:\conda\gliopath\Lib\site-packages\timm\models\_factory.py:138, in create_model(model_name, pretrained, pretrained_cfg, pretrained_cfg_overlay, checkpoint_path, cache_dir, scriptable, exportable, no_jit, **kwargs)
#     136 create_fn = model_entrypoint(model_name)
#     137 with set_layer_config(scriptable=scriptable, exportable=exportable, no_jit=no_jit):
# --> 138     model = create_fn(
#     139         pretrained=pretrained,
#     140         pretrained_cfg=pretrained_cfg,
#     141         pretrained_cfg_overlay=pretrained_cfg_overlay,
#     142         cache_dir=cache_dir,
#     143         **kwargs,
#     144     )
#     146 if checkpoint_path:
#     147     load_checkpoint(model, checkpoint_path)
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:416, in gigapath_slide_enc5l64d(**kwargs)
#     414 @register_model
#     415 def gigapath_slide_enc5l64d(**kwargs):
# --> 416     model = LongNetViT(embed_dim=64, depth=5, mlp_ratio=4, norm_layer=partial(nn.LayerNorm, eps=1e-6), **kwargs)
#     417     return model
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:257, in LongNetViT.__init__(self, in_chans, embed_dim, depth, slide_ngrids, tile_size, max_wsi_size, norm_layer, global_pool, dropout, drop_path_rate, **kwargs)
#     255 # get optimal segment length
#     256 segment_length = self.get_optimal_segment_length(max_wsi_size, tile_size)
# --> 257 self.encoder = make_longnet_from_name(self.encoder_name, drop_path_rate=drop_path_rate, dropout=dropout,
#     258                                       segment_length=segment_length)
#     259 self.norm = norm_layer(embed_dim)
#     260 # --------------------------------------------------------------------------
#
# File F:\workspace\pathology\gigapath\code\transfer\gliopath\models\longn.py:108, in make_longnet_from_name(config_name, dilated_ratio, segment_length, drop_path_rate, dropout)
#     105 if config_name in longnet_arch.__dict__.keys():
#     106     longnet_args = longnet_arch.__dict__[config_name]
# --> 108 longnet_args['dropout'] = dropout
#     109 longnet_args['drop_path_rate'] = drop_path_rate
#     111 # set dilated ratio and segment length
#
# UnboundLocalError: cannot access local variable 'longnet_args' where it is not associated with a value
