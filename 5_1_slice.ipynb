# %%
from gliopath.utils.slicer import tile_one_slide, tile_slides
import os
os.chdir('F:/workspace/pathology/gigapath')

# %%
slide_path = 'model/sample_data/PROV-000-000001.ndpi'
output_dir = 'output'
tile_one_slide(slide_path, save_dir=output_dir, level=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 slide_path = 'model/sample_data/PROV-000-000001.ndpi'
#       2 output_dir = 'output'
# ----> 3 tile_one_slide(slide_path, save_dir=output_dir, level=1)
#
# NameError: name 'tile_one_slide' is not defined

# %%
slide_paths = ['model/sample_data/PROV-000-000001.ndpi',
               'model/sample_data/PROV-000-000002.ndpi',
               'model/sample_data/PROV-000-000003.ndpi']
output_dir = 'output'
tile_slides(slide_paths, save_dir=output_dir, level=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 slide_path = 'model/sample_data/PROV-000-000001.ndpi'
#       2 output_dir = 'output'
# ----> 3 tile_one_slide(slide_path, save_dir=output_dir, level=1)
#
# NameError: name 'tile_one_slide' is not defined
