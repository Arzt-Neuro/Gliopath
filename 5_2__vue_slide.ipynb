# %%
from gliopath.utils.vue import vue_slide, vue_region, montrer_meta

# %%
path = '/mnt/f/workspace/pathology/gigapath/model/sample_data/PROV-000-000001.ndpi'

# %%
vue_slide(path)

# %%
vue_region(path)

# %%
montrer_meta(path)
